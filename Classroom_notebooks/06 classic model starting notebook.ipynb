# %%
import pandas as pd

# %%
#data_path = '~/Downloads/'
data_path = '../data/'

# %%
Customers = pd.read_csv(data_path + 'ClassicModels_Customers.csv', sep=';')

# %%
Customers.head(1)
# Out:
#    customerNumber       customerName contactLastName contactFirstName  \
# 0             103  Atelier graphique         Schmitt          Carine
#
#         phone    addressLine1 addressLine2    city state postalCode country  \
# 0  40.32.2555  54, rue Royale          NaN  Nantes   NaN      44000  France
#
#    salesRepEmployeeNumber  creditLimit  customerLocation
# 0                    1370      21000.0                 0

# %%
Employees = pd.read_csv(data_path + 'ClassicModels_Employees.csv', sep=';')

# %%
Employees.head(1)
# Out:
#    employeeNumber lastName firstName extension                         email  \
# 0            1002   Murphy     Diane     x5800  dmurphy@classicmodelcars.com
#
#    reportsTo   jobTitle  officeCode
# 0          0  President           1

# %%
Offices = pd.read_csv(data_path + 'ClassicModels_Offices.csv', sep=';')

# %%
Offices.head(1)
# Out:
#    officeCode           city            phone       addressLine1 addressLine2  \
# 0           1  San Francisco  +1 650 219 4782  100 Market Street    Suite 300
#
#   state country postalCode territory  officeLocation
# 0    CA     USA      94080       NaN               0

# %%
OrderDetails = pd.read_csv(data_path + 'ClassicModels_OrderDetails.csv', sep=';')

# %%
OrderDetails.head(1)
# Out:
#    orderNumber productCode  quantityOrdered  priceEach  orderLineNumber
# 0        10107    S10_1678               30      81.35                2

# %%
Orders = pd.read_csv(data_path + 'ClassicModels_Orders.csv', sep=';')

# %%
Orders.head(1)
# Out:
#    orderNumber            orderDate         requiredDate          shippedDate  \
# 0        10100  2003-01-06 00:00:00  2003-01-13 00:00:00  2003-01-10 00:00:00
#
#     status comments  customerNumber
# 0  Shipped      NaN             363

# %%
Payments = pd.read_csv(data_path + 'ClassicModels_Payments.csv', sep=';')

# %%
Payments.head(1)
# Out:
#   checkNumber          paymentDate   amount  customerNumber
# 0    AB661578  2004-07-28 00:00:00  9415.13             471

# %%
ProductLines = pd.read_csv(data_path + 'ClassicModels_ProductLines.csv', sep=';')

# %%
ProductLines.head(1)
# Out:
#     productLine                                    textDescription  \
# 0  Classic Cars  Attention car enthusiasts: Make your wildest c...
#
#    htmlDescription  image
# 0              NaN    NaN

# %%
Products = pd.read_csv(data_path + 'ClassicModels_Products.csv', sep=';')

# %%
Products.head(1)
# Out:
#   productCode                            productName productScale  \
# 0    S10_1678  1969 Harley Davidson Ultimate Chopper         1:10
#
#      productVendor                                 productDescription  \
# 0  Min Lin Diecast  This replica features working kickstand, front...
#
#    quantityInStock  buyPrice  MSRP  productLine
# 0             7933     48.81  95.7  Motorcycles

# %%
Employees.head()
# Out:
#    employeeNumber   lastName firstName extension  \
# 0            1002     Murphy     Diane     x5800
# 1            1056  Patterson      Mary     x4611
# 2            1076   Firrelli      Jeff     x9273
# 3            1088  Patterson   William     x4871
# 4            1102     Bondur    Gerard     x5408
#
#                              email  reportsTo              jobTitle  \
# 0     dmurphy@classicmodelcars.com          0             President
# 1   mpatterso@classicmodelcars.com       1002              VP Sales
# 2   jfirrelli@classicmodelcars.com       1002          VP Marketing
# 3  wpatterson@classicmodelcars.com       1056  Sales Manager (APAC)
# 4     gbondur@classicmodelcars.com       1056   Sale Manager (EMEA)
#
#    officeCode
# 0           1
# 1           1
# 2           1
# 3           6
# 4           4

# %%
Customers.head()
# Out:
#    customerNumber                customerName contactLastName  \
# 0             103           Atelier graphique         Schmitt
# 1             112          Signal Gift Stores            King
# 2             114  Australian Collectors, Co.        Ferguson
# 3             119           La Rochelle Gifts         Labrune
# 4             121          Baane Mini Imports      Bergulfsen
#
#   contactFirstName         phone                  addressLine1 addressLine2  \
# 0          Carine     40.32.2555                54, rue Royale          NaN
# 1             Jean    7025551838               8489 Strong St.          NaN
# 2            Peter  03 9520 4555             636 St Kilda Road      Level 3
# 3          Janine     40.67.8555  67, rue des Cinquante Otages          NaN
# 4           Jonas     07-98 9555        Erling Skakkes gate 78          NaN
#
#         city     state postalCode    country  salesRepEmployeeNumber  \
# ...

# %%
res=pd.merge(Employees, Customers, left_on='employeeNumber', right_on='salesRepEmployeeNumber', how='inner')

# %%
res[['firstName', 'lastName', 'customerName']]
# Out:
#    firstName   lastName                        customerName
# 0     Leslie   Jennings        Mini Gifts Distributors Ltd.
# 1     Leslie   Jennings                     Mini Wheels Co.
# 2     Leslie   Jennings                Technics Stores Inc.
# 3     Leslie   Jennings            Corporate Gift Ideas Co.
# 4     Leslie   Jennings           The Sharp Gifts Warehouse
# 5     Leslie   Jennings            Signal Collectibles Ltd.
# 6     Leslie   Thompson                  Signal Gift Stores
# 7     Leslie   Thompson                   Toys4GrownUps.com
# 8     Leslie   Thompson                   Boards & Toys Co.
# 9     Leslie   Thompson        Collectable Mini Designs Co.
# 10    Leslie   Thompson          Men 'R' US Retailers, Ltd.
# 11    Leslie   Thompson         West Coast Collectables Co.
# 12     Julie   Firrelli          Cambridge Collectables Co.
# 13     Julie   Firrelli            Online Mini Collectables
# 14     Julie   Firrelli                 Mini Creations Ltd.
# ...
