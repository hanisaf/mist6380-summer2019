# %%
#uncomment and run to install textblob
#import sys
#!{sys.executable} -m pip install textblob --user
#!{sys.executable} -m textblob.download_corpora --user

# %%
import pandas as pd
from textblob import TextBlob

# %% [markdown]
# # Sentiment analysis

# %%
song = """It's great to learn Python. But it's hard to learn it well.
Everything starts hard, but then becomes easy. So you should be happy,
because it all ends soon"""

# %%
blob = TextBlob(song)

# %%
blob.sentiment
# Out:
# Sentiment(polarity=0.29, subjectivity=0.7333333333333333)

# %%
for sent in blob.sentences:
    print(sent, sent.sentiment)
# Out:
# It's great to learn Python. Sentiment(polarity=0.8, subjectivity=0.75)
# But it's hard to learn it well. Sentiment(polarity=-0.2916666666666667, subjectivity=0.5416666666666666)
# Everything starts hard, but then becomes easy. Sentiment(polarity=0.07083333333333333, subjectivity=0.6875)
# So you should be happy,
# because it all ends soon Sentiment(polarity=0.8, subjectivity=1.0)

# %%
blob.sentiment
# Out:
# Sentiment(polarity=0.29, subjectivity=0.7333333333333333)

# %% [markdown]
# # What is the most positive sentence, and the most negative sentence in the first earning call

# %%
data = pd.read_csv('../data/EC2000.csv.gz')

# %% [markdown]
# 1- drop first column index, rename fName to company, drop the last three columns

# %%
data2 = data.drop('index', axis='columns')

# %%
data3 = data2.rename({'fName':'company'}, axis='columns')

# %%
last_three_cols = data3.columns[-3:]

# %%
data4 = data3.drop(last_three_cols, axis='columns')

# %%
data4.head()
# Out:
#       id                                               text  \
# 0  32934  Zoe's Kitchen, Inc. (NYSE:ZOES)\nQ2 2015 Earni...
# 1  32905  Autodesk, Inc. (NASDAQ:ADSK)\nQ2 2016 Earnings...
# 2  32926  Smith & Wesson Holding Corp. (NASDAQ:SWHC)\nQ1...
# 3  32930  Ulta Salon, Cosmetics & Fragrance, Inc. (NASDA...
# 4  32907  Splunk Inc. (NASDAQ:SPLK)\nQ2 2016 Earnings Co...
#
#                   date                                  company  \
# 0  2015-08-28 00:11:00                      Zoe's Kitchen, Inc.
# 1  2015-08-28 00:07:00                           Autodesk, Inc.
# 2  2015-08-27 23:25:00       Smith & Wesson Holding Corporation
# 3  2015-08-27 23:09:00  Ulta Salon, Cosmetics & Fragrance, Inc.
# 4  2015-08-27 22:56:00                              Splunk Inc.
#
#               sector
# 0  Consumer Services
# 1         Technology
# 2      Capital Goods
# 3  Consumer Services
# 4         Technology

# %%
text1 = data4.iloc[0].text

# %%
blob = TextBlob(text1)

# %%
blob.sentiment
# Out:
# Sentiment(polarity=0.140799481822049, subjectivity=0.4249167174308212)

# %%
for sent in blob.sentences:
    print(sent, sent.sentiment)
# Out:
# Zoe's Kitchen, Inc. (NYSE:ZOES)
# Q2 2015 Earnings Call
# August 27, 2015 5:00 pm ET
# Executives
# James Besch - CFO, Vice President-Accounting & Controller
# Kevin Miles - President, Chief Executive Officer & Director
# Analysts
# Karen F. Short - Deutsche Bank Securities, Inc.
# Andrew Marc Barish - Jefferies LLC
# Nicole M. Miller Regan - Piper Jaffray & Co (Broker)
# Will Slabaugh - Stephens, Inc.
# Jason West - Credit Suisse Securities (NYSE:USA) LLC (Broker)
# Sharon M. Zackfia - William Blair & Co. LLC
# David E. Tarantino - Robert W. Baird & Co., Inc. (Broker)
# Paul Westra - Stifel, Nicolaus & Co., Inc.
# Stephen Anderson - Maxim Group
# Operator
# Good day, ladies and gentlemen, and thank you for standing by. Sentiment(polarity=0.35, subjectivity=0.45000000000000007)
# Welcome to the Zoe's Kitchen Second Quarter 2015 Earnings Conference Call. Sentiment(polarity=0.4, subjectivity=0.45)
# At this time, all participants have been placed in a listen-only mode, and the lines will be open for your questions following the presentation. Sentiment(polarity=0.0, subjectivity=0.3)
# Please note that this conference is being recorded today, August 27, 2015. Sentiment(polarity=0.0, subjectivity=0.0)
# On the call today, we have Kevin Miles, President and Chief Executive Officer; and Jim Besch, Principal Financial Officer. Sentiment(polarity=0.0, subjectivity=0.0)
# Now I'd like to turn the conference over to Jim Besch. Sentiment(polarity=0.0, subjectivity=0.0)
# Please go ahead. Sentiment(polarity=0.0, subjectivity=0.0)
# James Besch - CFO, Vice President-Accounting & Controller
# Thank you, operator, and good afternoon. Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# By now, everyone should have access to our second quarter 2015 earnings release. Sentiment(polarity=0.0, subjectivity=0.0)
# If not, it can be found at www.zoeskitchen.com in the Investor Relations section. Sentiment(polarity=0.0, subjectivity=0.0)
# Before we begin our formal remarks, I need to remind everyone that part of our discussions today will include forward-looking statements. Sentiment(polarity=0.0, subjectivity=0.0)
# These forward-looking statements are not guarantees of future performance and, therefore, you should not put undue reliance on them. Sentiment(polarity=0.0, subjectivity=0.125)
# These statements are also subject to numerous risks and uncertainties that could cause actual results to differ materially from what we expect. Sentiment(polarity=-0.05555555555555555, subjectivity=0.31111111111111106)
# We refer all of you to our recent SEC filings for a more detailed discussion of the risks that could impact our future operating results and financial condition. Sentiment(polarity=0.13333333333333333, subjectivity=0.37083333333333335)
# Also during today's call, we will discuss non-GAAP measures, which we believe can be useful in evaluating our performance. Sentiment(polarity=0.3, subjectivity=0.0)
# The presentation of this additional information should not be considered in isolation or as a substitute for results prepared in accordance with GAAP, and a reconciliation to comparable GAAP measures is available in our earnings release. Sentiment(polarity=0.4, subjectivity=0.4)
# With that, I would like to turn the call over to Kevin Miles. Sentiment(polarity=0.0, subjectivity=0.0)
# Kevin Miles - President, Chief Executive Officer & Director
# Thanks, Jim. Sentiment(polarity=0.2, subjectivity=0.2)
# Good afternoon, everyone, and thank you for joining us on the call today. Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# I'm pleased to report our second quarter results that demonstrated a continuation of the strong operating momentum we've had this year. Sentiment(polarity=0.3111111111111111, subjectivity=0.5777777777777778)
# Highlights for the 12-week period ending July 13, 2015, include revenue growth of over 30%, comparable restaurant sales growth of 5.6%, marking our 22nd consecutive quarter of positive comparable restaurant sales growth driven once again by increases in traffic, mix, average check, and adjusted EBITDA growth of over 28%. Sentiment(polarity=0.038636363636363635, subjectivity=0.47272727272727266)
# Seven new company-owned restaurants opened during this quarter. Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# We believe that the strength and the consistency of our results continue to demonstrate the distinctive positioning of our brand. Sentiment(polarity=0.0, subjectivity=0.0)
# At Zoe's Kitchen, our mission is to deliver goodness with fresh better-for-you options served with genuine Southern hospitality. Sentiment(polarity=0.2333333333333333, subjectivity=0.3333333333333333)
# It's our unwavering commitment to this mission that we view as one of our most important and unique differentiators and one that we think continues to build a strong emotional connection to our guests. Sentiment(polarity=0.3416666666666667, subjectivity=0.7766666666666666)
# One of my favorite things to talk about is our team. Sentiment(polarity=0.5, subjectivity=1.0)
# Quarter two marks our 20th anniversary and we recognize the milestone with 20 years of goodness celebration companywide. Sentiment(polarity=0.0, subjectivity=0.0)
# Throughout this summer we have team members to nominate colleagues and guests that embody our mission of delivering goodness and the values of living Zoe's. Sentiment(polarity=0.0, subjectivity=0.0)
# Hundreds of team members were nominated and each of these team members will be recognized – have a special recognition for the impact that they make on our brand. Sentiment(polarity=0.35714285714285715, subjectivity=0.5714285714285714)
# One of the comment that stood out to me was about Aldo, a kitchen leader in Cherry Hill, New Jersey. Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# Aldo lives Zoe's every single day. Sentiment(polarity=-0.07142857142857142, subjectivity=0.21428571428571427)
# He goes above and beyond in every opportunity possible. Sentiment(polarity=0.0, subjectivity=0.55)
# Aldo is truly happy when he is helping others. Sentiment(polarity=0.8, subjectivity=1.0)
# You can hear him chatting with guests from the kitchen while they're ordering. Sentiment(polarity=0.0, subjectivity=0.0)
# I tell the team frequently that living Zoe's is more than just words, it's your desire to put others first and individually share your talents. Sentiment(polarity=0.2125, subjectivity=0.3833333333333333)
# Aldo is one of many who are contributing to this exceptional culture. Sentiment(polarity=0.5833333333333333, subjectivity=0.75)
# The ongoing investment in our team also includes regular evaluations of systems and practices in order to us – o further optimize our operation which in turn improves the guest experience. Sentiment(polarity=0.0, subjectivity=0.28846153846153844)
# We've been testing a new KDS system as a way to gain more insight to this speed of service. Sentiment(polarity=0.3181818181818182, subjectivity=0.4772727272727273)
# This is particularly important as we continue to grow our average unit volumes. Sentiment(polarity=0.125, subjectivity=0.7)
# We've been very pleased with the early result of the tests, which is currently in four locations. Sentiment(polarity=0.25, subjectivity=0.5666666666666668)
# All of our system improvements have the same objective, an exceptional guest experience where we can showcase our differentiated menu of freshly prepared Mediterranean-inspired dishes served with Southern hospitality. Sentiment(polarity=0.1933333333333333, subjectivity=0.34500000000000003)
# On the development front, we opened seven new company-owned Zoe's Kitchen restaurants bringing our year-to-date development at the end of second quarter to 151. Sentiment(polarity=0.06818181818181818, subjectivity=0.22727272727272727)
# Subsequent to the end of the quarter, we've opened an additional seven restaurants bringing our total number of restaurants to 158. Sentiment(polarity=0.0, subjectivity=0.4)
# We remain pleased with the performance of our newer units including the early results of our 2015 class of restaurants which bolsters our confidence in our hub-and-spoke strategy and a wide acceptance of our brand. Sentiment(polarity=0.16666666666666666, subjectivity=0.5666666666666668)
# We continue to expect to open 31 to 33 new company-owned restaurants this year and have leases signed for the balance of 2015 development. Sentiment(polarity=0.06818181818181818, subjectivity=0.4772727272727273)
# In addition, we have approximately 75% of our leases signed for 2015 pipeline, which includes the newest hub in Denver, Colorado. Sentiment(polarity=-0.4, subjectivity=0.6)
# We currently have three leases signed in Denver. Sentiment(polarity=0.0, subjectivity=0.4)
# We will continue to identify new opportunities as we have previously stated. Sentiment(polarity=-0.015151515151515152, subjectivity=0.3106060606060606)
# This strategy will build awareness in the first 12 to 18 months in this new hub market. Sentiment(polarity=0.19318181818181818, subjectivity=0.3939393939393939)
# We remained confident that we will continue to successfully operate more than 1600 domestic restaurants over the long term. Sentiment(polarity=0.33999999999999997, subjectivity=0.5566666666666666)
# I would like to turn the call over to Jim for detailed discussions of our second quarter financial results. Sentiment(polarity=0.13333333333333333, subjectivity=0.25)
# James Besch - CFO, Vice President-Accounting & Controller
# Thanks, Kevin. Sentiment(polarity=0.2, subjectivity=0.2)
# For the 12-week period ended July 13, 2015, total revenue increased 30.0% to $54.5 million from $41.9 million in the second quarter last year. Sentiment(polarity=0.0, subjectivity=0.2722222222222222)
# Company-owned restaurant sales increased 30.3% to $54.4 million compared to $41.8 million in the year-ago period. Sentiment(polarity=0.0, subjectivity=0.0)
# The increase in restaurant sales was largely due to the addition of 29 new company-owned restaurants since the second quarter of last year combined with the acquisition of three franchise restaurants in November of 2014. Sentiment(polarity=0.0028409090909090884, subjectivity=0.2240530303030303)
# As Kevin noted, comparable restaurant sales increased 5.6% during the second quarter. Sentiment(polarity=0.0, subjectivity=0.0)
# The increase consisted of a 1.3% increase in traffic, a 3.5% increase in mix, and a 0.8% increase in price. Sentiment(polarity=0.0, subjectivity=0.0)
# As a reminder, restaurants enter our comparable base after they are open for 18 periods. Sentiment(polarity=-0.4, subjectivity=0.75)
# Our comparable base consisted of 105 restaurants at the end of our second quarter. Sentiment(polarity=-0.4, subjectivity=0.5)
# Turning now to expenses. Sentiment(polarity=0.0, subjectivity=0.0)
# For the second quarter, cost of goods sold as a percentage of restaurant sales, was 31.8%. Sentiment(polarity=0.0, subjectivity=0.0)
# While we continue to see year-over-year improvement in cost of sales as a result of new annual pricing agreements for feta cheese, olive oil, and produce, we did see a sequential uptick in costs resulting from increases in chicken and produce partially offset by lower paper product costs. Sentiment(polarity=-0.18787878787878787, subjectivity=0.5681818181818182)
# Looking ahead, poultry prices remained elevated compared to last year, and we have several produce items currently under Act of God pricing, specifically onions, bell peppers, cucumbers zucchini, and cherry tomatoes. Sentiment(polarity=0.0, subjectivity=0.15555555555555556)
# As a result, we currently anticipate third quarter cost of sales of 32.2% and slightly under 32% for the full year. Sentiment(polarity=0.04583333333333333, subjectivity=0.2791666666666667)
# Labor cost as a percentage of restaurant sales increased 40 basis points year-over-year to 27.6%. Sentiment(polarity=0.0, subjectivity=0.0)
# As we discussed last quarter, the increase was driven by an increase in the number of training stores, and ongoing costs associated with developing our management bench to support future growth. Sentiment(polarity=0.0, subjectivity=0.09583333333333333)
# These increases were partially offset by leverage on comparable store sales growth. Sentiment(polarity=-0.1, subjectivity=0.3)
# Store operating expenses rose to 19.3% of restaurant sales during the second quarter, an increase of 180 basis points compared to the prior-year period. Sentiment(polarity=0.3, subjectivity=0.475)
# Store operating expenses included approximately $230,000 of restaurant-level expenses related to our annual general managers conference, which was held in the second quarter of 2015 as opposed to the first quarter in 2014. Sentiment(polarity=-0.019999999999999997, subjectivity=0.36666666666666664)
# Excluding this timing difference store, operating expense margin increased 140 basis points compared to last year. Sentiment(polarity=0.0, subjectivity=0.06666666666666667)
# The increase was driven primarily by the normalization of repair and maintenance costs compared to the prior year as we did not incur a full quarter of preventative maintenance as a result of escalating issues with our former maintenance vendor. Sentiment(polarity=0.1875, subjectivity=0.2625)
# We also experienced higher occupancy expenses as a percentage of restaurant sales compared to prior year. Sentiment(polarity=0.35000000000000003, subjectivity=0.4666666666666666)
# Overall, in the second quarter, restaurant contribution increased 31.2% to $11.6 million from $8.8 million last year. Sentiment(polarity=0.0, subjectivity=0.022222222222222223)
# Restaurant contribution margin as a percentage of restaurant sales, improved approximately 10 basis points year-over-year to 21.3%. Sentiment(polarity=-0.4, subjectivity=0.6)
# General and administrative costs increased by $1.8 million to $6.3 million in the second quarter of 2015, up from $4.5 million in the prior-year quarter. Sentiment(polarity=0.02500000000000001, subjectivity=0.25)
# G&A expenses in the quarter included approximately $550,000 related to executive transition costs, approximately $180,000 related to the timing of our 2015 GM Conference as discussed previously, and approximately $100,000 related to the breakage of the lease at our Riverside location in Jacksonville, Florida, in conjunction with the relocation of the restaurant. Sentiment(polarity=-0.19523809523809524, subjectivity=0.4523809523809524)
# Excluding these unusual items, in addition to $142,000 of certain IPO-related expenses in the second quarter of last year, G&A as a percent of total revenues decreased approximately 40 basis points in the prior-year quarter. Sentiment(polarity=-0.05510204081632654, subjectivity=0.5268707482993197)
# Looking forward with regard to G&A, at the end of our second quarter our public float held by non-affiliates exceeded $700 million, and as a result we no longer qualify as an emerging growth company under the JOBS Act. Sentiment(polarity=0.0, subjectivity=0.03333333333333333)
# In addition to changes in certain accounting and reporting requirements, we will now be required by the SEC to be SOX compliant as a large accelerated filer by the year-end 2015. Sentiment(polarity=0.10952380952380951, subjectivity=0.5333333333333333)
# While we have been ahead of schedule in preparing for many of these requirements, the performance of our stock as of July 13, 2015, has resulted in an acceleration of certain procedures that were not planned for at the beginning of the year. Sentiment(polarity=0.35714285714285715, subjectivity=0.5357142857142857)
# As a result, we expect to incur approximately $500,000 of incremental costs associated with our integrated audit requirement and other professional services, as well as additional head count. Sentiment(polarity=-0.1416666666666667, subjectivity=0.35833333333333334)
# Pre-opening cost increased to $637,000 from $442,000 in the second quarter of 2014, due primarily to the timing of the unit openings. Sentiment(polarity=0.09166666666666667, subjectivity=0.2916666666666667)
# Looking ahead, we expect the 31 to 33 openings for 2015 to result in pre-opening costs of approximately $2.7 million for the full year including approximately $800,000 in the third quarter. Sentiment(polarity=-0.11250000000000002, subjectivity=0.4375)
# Interest expense was approximately $710,000 compared to $620,000 in the second quarter of 2014. Sentiment(polarity=-0.2, subjectivity=0.3)
# Our reported interest expense currently represents noncash expenses related to our deemed landlord financing. Sentiment(polarity=0.0, subjectivity=0.4)
# For the remaining quarters, we believe that our second quarter expense should provide a useful guide for modeling approximately $750,000 per quarter. Sentiment(polarity=-0.03333333333333335, subjectivity=0.19999999999999998)
# Provision for income taxes was $871,000 in the second quarter, as compared to a benefit of $124,000 in the year-ago period. Sentiment(polarity=0.0, subjectivity=0.0)
# Our annual tax provision is derived from the book-to-tax difference created by our goodwill intangible. Sentiment(polarity=0.0, subjectivity=0.0)
# The annual provision for taxes is spread quarterly based on the pre-tax income loss and the forecasted pre-tax income loss for the full year. Sentiment(polarity=0.35, subjectivity=0.55)
# Net income for the quarter was $120,000 or $0.01 per share, as compared to a $1.1 million in the second quarter of 2014 or $0.06 per share. Sentiment(polarity=0.0, subjectivity=0.0)
# Weighted average diluted shares outstanding were $19.6 million for the second quarter of 2015 compared with $19.5 million in the year-ago period. Sentiment(polarity=0.11666666666666665, subjectivity=0.425)
# To account for the impact of our April 2014 IPO and the resulting change to our capital structure as well as other one-time adjustments, we've calculated adjusted net income. Sentiment(polarity=-0.0625, subjectivity=0.1875)
# Our adjusted results reflect our post-IPO capital structure, including our basic and diluted share count as if the IPO occurred prior to the beginning of 2014. Sentiment(polarity=0.0, subjectivity=0.0625)
# Attached to our press release, you'll find a reconciliation of our GAAP results to our adjusted financial results. Sentiment(polarity=0.0, subjectivity=0.0)
# We believe that the adjusted results provide a useful view of our business given our current capital structure and post-IPO cost structure. Sentiment(polarity=0.15, subjectivity=0.2)
# Adjusted net income for the second quarter of 2015 was $955,000 or $0.05 per share versus $705,000 or $0.04 per share in the second quarter of 2014. Sentiment(polarity=0.0, subjectivity=0.0)
# With that, I'd like to turn the call back over to Kevin for closing remarks. Sentiment(polarity=0.0, subjectivity=0.0)
# Kevin Miles - President, Chief Executive Officer & Director
# Thanks, Jim. Sentiment(polarity=0.2, subjectivity=0.2)
# Before I close, I'd like to provide our updated outlook for 2015. Sentiment(polarity=0.0, subjectivity=0.0)
# We currently expect restaurant sales between $220 million and $224 million and royalty fees to be approximately $200,000. Sentiment(polarity=-0.2, subjectivity=0.5)
# We expect comparable restaurant sales growth of 5% to 6%. Sentiment(polarity=0.0, subjectivity=0.0)
# Keep in mind that we lapped last year's approximately 1.3% price increase in July and we currently don't intend to take price for the remainder of 2015. Sentiment(polarity=-0.13333333333333333, subjectivity=0.35555555555555557)
# Our restaurant contribution margin is expected to range between 20.0% and 20.5%. Sentiment(polarity=-0.1, subjectivity=0.4)
# We plan on opening 31 to 33 company-owned restaurants during the year. Sentiment(polarity=0.0, subjectivity=0.0)
# And finally, we expect G&A expenses to be between $25.3 million and $25.5 million, excluding executive transition cost. Sentiment(polarity=0.0, subjectivity=1.0)
# With that, we take great pride in delivering goodness to our team and our guests by embodying the four pillars of the Mediterranean lifestyle: eat, cook, live, and connect Mediterranean. Sentiment(polarity=0.4681818181818182, subjectivity=0.625)
# We continue to inspire our guests to focus on the value of the food they consume, enjoy the experiences with family and friends, and feel benefits associated with choosing meals that fuel an active and healthy lifestyle, allowing them to live life to the fullest. Sentiment(polarity=0.22575757575757577, subjectivity=0.525)
# We remain excited about our plan to bring wholesome, freshly prepared Mediterranean dishes to guests across the country and are committed to capitalizing on the large opportunity we see ahead to grow and strengthen our brand, ultimately rewarding our shareholders over the long term. Sentiment(polarity=0.26785714285714285, subjectivity=0.6157142857142858)
# Before we take questions, I'd like to take a moment to thank each Zoe's team member. Sentiment(polarity=0.0, subjectivity=0.0)
# I mean it when I say that each of you who continue to deliver goodness to your colleagues and our guests that are building our business and our brand. Sentiment(polarity=-0.3125, subjectivity=0.6875)
# When you come to work each day you're not only helping people live Mediterranean; you're building a team that's empowered to make a difference. Sentiment(polarity=0.06818181818181818, subjectivity=0.75)
# Together, we've grown Zoe's Kitchen into a brand I'm truly honored to be a part of, and I'll see you in a restaurant soon. Sentiment(polarity=0.0, subjectivity=0.0)
# Thanks, everyone, for your interest in our company. Sentiment(polarity=0.2, subjectivity=0.2)
# And now we're happy to answer any questions you may have. Sentiment(polarity=0.8, subjectivity=1.0)
# Operator, you can open the line. Sentiment(polarity=0.0, subjectivity=0.5)
# Question-and-Answer Session
# Operator
# Thank you. Sentiment(polarity=0.0, subjectivity=0.0)
# At this time we'll be conducting a question-and-answer session. Sentiment(polarity=0.0, subjectivity=0.0)
# Our first question comes from Karen Short from Deutsche Bank. Sentiment(polarity=0.125, subjectivity=0.31666666666666665)
# Karen F. Short - Deutsche Bank Securities, Inc.
# Hey thanks for taking my question. Sentiment(polarity=0.1, subjectivity=0.25)
# I guess just a little clarification. Sentiment(polarity=-0.1875, subjectivity=0.5)
# Your top-line guidance was raised. Sentiment(polarity=0.0, subjectivity=0.0)
# Your contribution margin was a little better than expected in the second quarter. Sentiment(polarity=0.053125, subjectivity=0.35)
# So I guess I'm just curious why not raise the restaurant contribution margin for the full year given the beat and strong margins. Sentiment(polarity=0.22777777777777775, subjectivity=0.7611111111111111)
# Are you just staying conservative, or anything to point to there? Sentiment(polarity=0.0, subjectivity=0.0)
# Kevin Miles - President, Chief Executive Officer & Director
# Hi, Karen. Sentiment(polarity=0.0, subjectivity=0.0)
# This is Kevin. Sentiment(polarity=0.0, subjectivity=0.0)
# Yeah, I think – and Jimmy can jump in. Sentiment(polarity=0.0, subjectivity=0.0)
# But we still – just to kind of point you back, the back half of our year kind of being the holidays, and going into Q3-Q4, kind of slows and ramps downward in the back half of the year. Sentiment(polarity=0.18333333333333332, subjectivity=0.37916666666666665)
# We do have some openings, and that as well contribute into that kind of dip – a little bit of our margin there. Sentiment(polarity=0.20625, subjectivity=0.7)
# Karen F. Short - Deutsche Bank Securities, Inc. Sentiment(polarity=0.0, subjectivity=0.3)
# Okay. Sentiment(polarity=0.5, subjectivity=0.5)
# And then I guess just curious if you could give a little color on the cadence of the comp in the quarter, and I guess if there was any weather impact on the comp. Sentiment(polarity=-0.14375, subjectivity=0.75)
# Obviously, you were asked about that in the first quarter because there had been some bad weather into the very early part of the second quarter. Sentiment(polarity=-0.06399999999999997, subjectivity=0.378)
# Kevin Miles - President, Chief Executive Officer & Director
# Yeah, the cadence, really, it really wasn't any difference throughout the quarter. Sentiment(polarity=0.2, subjectivity=0.2)
# We did see little a weather as everybody is aware of in Texas, which is our biggest market. Sentiment(polarity=0.03125, subjectivity=0.375)
# But really, the cadence was throughout each of the three periods kind of equally the same. Sentiment(polarity=0.2, subjectivity=0.36875)
# Karen F. Short - Deutsche Bank Securities, Inc.
# And any color on how much the weather might have impacted the comps? Sentiment(polarity=0.1, subjectivity=0.25)
# Kevin Miles - President, Chief Executive Officer & Director
# We never have really identified weather. Sentiment(polarity=0.2, subjectivity=0.2)
# It did impact our patio business and some people trying to get out of cars not wanting to get wet, but we did equate any impact of that. Sentiment(polarity=-0.1, subjectivity=0.4)
# But you could assume there is some slight impact to that weather outlook, kind of the first part of Q2. Sentiment(polarity=0.22777777777777777, subjectivity=0.4666666666666666)
# Karen F. Short - Deutsche Bank Securities, Inc. Sentiment(polarity=0.0, subjectivity=0.3)
# Okay. Sentiment(polarity=0.5, subjectivity=0.5)
# And then just the last question I had, in your prepared remarks you actually – I think you said that poultry was a headwind for you in this quarter, but in your Q you actually called it out as a tailwind. Sentiment(polarity=0.0, subjectivity=0.0888888888888889)
# I just wanted to clarify that I heard that right. Sentiment(polarity=0.2857142857142857, subjectivity=0.5357142857142857)
# James Besch - CFO, Vice President-Accounting & Controller
# Yeah. Sentiment(polarity=0.0, subjectivity=0.0)
# I'm sorry. Sentiment(polarity=-0.5, subjectivity=1.0)
# Can you actually repeat that? Sentiment(polarity=0.0, subjectivity=0.1)
# Karen F. Short - Deutsche Bank Securities, Inc.
# Well, I think in your prepared remarks, as it related to COGS, you called out poultry as a headwind for you in the quarter, but in your Q I think you actually called it out as a benefit. Sentiment(polarity=0.0, subjectivity=0.26666666666666666)
# James Besch - CFO, Vice President-Accounting & Controller
# So, in the year-over-year quarter, it is a benefit. Sentiment(polarity=0.0, subjectivity=0.0)
# But when we were looking at sequential from last quarter to this quarter, there was a slight uptick. Sentiment(polarity=-0.08333333333333333, subjectivity=0.11666666666666667)
# With that being said, I think we're anticipating for it to remain fairly flat here in the third quarter and hoping to see some decrease at the end of the year. Sentiment(polarity=-0.0125, subjectivity=0.0625)
# Karen F. Short - Deutsche Bank Securities, Inc.
# Great. Sentiment(polarity=0.4, subjectivity=0.525)
# Thanks very much. Sentiment(polarity=0.23, subjectivity=0.23)
# Operator
# Thank you. Sentiment(polarity=0.0, subjectivity=0.0)
# Our next question from Andy Barish from Jefferies. Sentiment(polarity=0.0, subjectivity=0.0)
# Andrew Marc Barish - Jefferies LLC
# Hey, guys. Sentiment(polarity=0.0, subjectivity=0.0)
# Just wondering on some of the same-store sales composition. Sentiment(polarity=0.0, subjectivity=0.0)
# I know mix looked like it really kind of continued to pick up and be a big driver in the 2Q. Sentiment(polarity=0.3, subjectivity=0.5)
# Is there anything specific going on that you can point to other than some of the new menu items you rolled out at the beginning of the year? Sentiment(polarity=0.0037878787878787845, subjectivity=0.3181818181818182)
# Kevin Miles - President, Chief Executive Officer & Director
# Hey, Andy, this is Kevin. Sentiment(polarity=0.0, subjectivity=0.0)
# Yeah, now – the biggest driver in the quarter, really – back to mix, just to kind of point everybody back on the mix, much of that mix is the catering traffic that goes through that, as we count a catering customer equal to a dine-in customer. Sentiment(polarity=0.16, subjectivity=0.27)
# So some of that mix is all driven predominantly by catering. Sentiment(polarity=0.0, subjectivity=0.0)
# That said, we've really seen the Hummus Trio and the two new hummuses as well as the Med Chicken Dinner drive some impact, which is a lot of where you'll see coming from in the price area. Sentiment(polarity=-0.08787878787878788, subjectivity=0.5348484848484848)
# It is kind of significantly where you're seeing that, because the uptick both of those items are at a higher price point. Sentiment(polarity=0.4083333333333334, subjectivity=0.7583333333333333)
# Andrew Marc Barish - Jefferies LLC
# And I guess is this seasonally a stronger catering business in the 2Q? Sentiment(polarity=0.0, subjectivity=0.0)
# Just kind of wondering if there is a little more color on that. Sentiment(polarity=0.30416666666666664, subjectivity=0.6333333333333333)
# Kevin Miles - President, Chief Executive Officer & Director
# Not really. Sentiment(polarity=-0.1, subjectivity=0.2)
# It's a relatively flat. Sentiment(polarity=-0.025, subjectivity=0.125)
# Kind of it ramps up. Sentiment(polarity=0.6, subjectivity=0.9)
# It has the first part of Q1. Sentiment(polarity=0.25, subjectivity=0.3333333333333333)
# It kind of goes equally through until the back part of Q3, and then kind of declines going into the holidays. Sentiment(polarity=0.3, subjectivity=0.5125)
# Andrew Marc Barish - Jefferies LLC
# Okay. Sentiment(polarity=0.5, subjectivity=0.5)
# And then just finally, you had – back on the cost of goods, you had negative 4% basket in the 1Q. Sentiment(polarity=-0.09999999999999999, subjectivity=0.4666666666666666)
# Jim, do you have the 2Q number off the top of your head? Sentiment(polarity=0.5, subjectivity=0.5)
# James Besch - CFO, Vice President-Accounting & Controller
# We don't have that comparison going into Q2. Sentiment(polarity=0.0, subjectivity=0.0)
# Andrew Marc Barish - Jefferies LLC
# Okay. Sentiment(polarity=0.5, subjectivity=0.5)
# Thanks. Sentiment(polarity=0.2, subjectivity=0.2)
# Operator
# Thank you. Sentiment(polarity=0.0, subjectivity=0.0)
# Our next question comes from Nicole Miller from Piper Jaffray. Sentiment(polarity=0.0, subjectivity=0.0)
# Nicole M. Miller Regan - Piper Jaffray & Co (Broker)
# Thanks. Sentiment(polarity=0.2, subjectivity=0.2)
# Good afternoon. Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# Could you just talk a little bit about your – more about your speed of service initiative? Sentiment(polarity=0.15625, subjectivity=0.5)
# And how are you comping at peak meal periods around lunch and dinner and how might that impact that? Sentiment(polarity=0.0, subjectivity=0.0)
# Thanks. Sentiment(polarity=0.2, subjectivity=0.2)
# Kevin Miles - President, Chief Executive Officer & Director
# Yes. Sentiment(polarity=0.0, subjectivity=0.0)
# Hey, Nicole. Sentiment(polarity=0.0, subjectivity=0.0)
# This is Kevin. Sentiment(polarity=0.0, subjectivity=0.0)
# You know we're still early stages. Sentiment(polarity=0.1, subjectivity=0.3)
# We're, I guess, now three months or so into our two – three or four stores that we've rolled out. Sentiment(polarity=0.0, subjectivity=0.0)
# We're analyzing that data right now. Sentiment(polarity=0.2857142857142857, subjectivity=0.5357142857142857)
# We believe, again, long-term, that it is absolutely a throughput enhancer for us. Sentiment(polarity=0.2, subjectivity=0.9)
# Don't have enough data to share with you at this point, but all signs and tests point to very positive results, especially just in the kind of culture side of the business, the team building on the ability to have an ease of use and be able to focus just directly on what they need to focus on. Sentiment(polarity=0.24924242424242427, subjectivity=0.6890151515151515)
# So from that standpoint, the test is going really well, but no data to give you as far as how much it is increasing throughput or anything at this point. Sentiment(polarity=0.16666666666666666, subjectivity=0.4666666666666666)
# And we still have intent for a 2016-type rollout unless we have any major glitches along the way. Sentiment(polarity=0.0625, subjectivity=0.5)
# And then, I'm sorry, the back half of the year – you said lunch and dinner. Sentiment(polarity=-0.2222222222222222, subjectivity=0.3888888888888889)
# At this point, we're seeing comp through lunch – it's kind of really all dayparts – just to kind of break it down, catering in growing the comp about a third, lunch a third, dinner a third, is really what we're seeing. Sentiment(polarity=0.18055555555555552, subjectivity=0.3111111111111111)
# So as far as what does KDS do for that, again, don't have enough insight to that. Sentiment(polarity=0.05, subjectivity=0.75)
# Today, I do think the biggest enhancer will be at lunch time from a throughput standpoint. Sentiment(polarity=0.0, subjectivity=0.0)
# Nicole M. Miller Regan - Piper Jaffray & Co (Broker)
# Thank you. Sentiment(polarity=0.0, subjectivity=0.0)
# And a last quick one if I may. Sentiment(polarity=0.16666666666666666, subjectivity=0.2833333333333333)
# Your development has been absolutely on target on time, if not even a little bit faster. Sentiment(polarity=0.0062500000000000056, subjectivity=0.7)
# Does that give you more confidence, obviously, about hitting 4Q openings and being at the higher end or even the ability to look out into next year and be signing and looking at developments? Sentiment(polarity=0.1875, subjectivity=0.375)
# How does that give you incremental confidence? Sentiment(polarity=0.0, subjectivity=0.0)
# Kevin Miles - President, Chief Executive Officer & Director
# We're very confident. Sentiment(polarity=0.65, subjectivity=1.0)
# The development team has done an outstanding job. Sentiment(polarity=0.5, subjectivity=0.875)
# We've gone across the country. Sentiment(polarity=0.0, subjectivity=0.0)
# We're really excited about going into Denver. Sentiment(polarity=0.375, subjectivity=0.75)
# It'll be our first market that we've got several leases signed in quickly. Sentiment(polarity=0.19444444444444442, subjectivity=0.27777777777777773)
# Kansas City opened extremely well. Sentiment(polarity=-0.125, subjectivity=1.0)
# So, it was approximately 75% of our 2016 pipeline baked already. Sentiment(polarity=-0.4, subjectivity=0.6)
# I feel very, very confident going into 2016 that we can see some openings get opened in the first part of the year. Sentiment(polarity=0.45, subjectivity=0.6666666666666666)
# It'd be really strong opening for us. Sentiment(polarity=0.4333333333333333, subjectivity=0.7333333333333333)
# Nicole M. Miller Regan - Piper Jaffray & Co (Broker)
# Thanks again. Sentiment(polarity=0.2, subjectivity=0.2)
# Kevin Miles - President, Chief Executive Officer & Director
# Thank you. Sentiment(polarity=0.0, subjectivity=0.0)
# Operator
# Thank you. Sentiment(polarity=0.0, subjectivity=0.0)
# Our next question comes from William Slabaugh from Stephens. Sentiment(polarity=0.0, subjectivity=0.0)
# Will Slabaugh - Stephens, Inc.
# Yeah. Sentiment(polarity=0.0, subjectivity=0.0)
# Thanks, guys. Sentiment(polarity=0.2, subjectivity=0.2)
# Kevin, you mentioned the 2015 stores opening up well, and from the previous question kind of touching on the overall kind of positive signs you've seen in the previous classes. Sentiment(polarity=0.2277056277056277, subjectivity=0.4541125541125541)
# So I'm just curious if you had any commentary around is the 2013 class and the 2014 class also shaping up as you would have hoped they would be shaping up at this point? Sentiment(polarity=-0.1, subjectivity=1.0)
# And is there any geographical differences you can point to as you go into some of these new markets like Kansas City or some of the more northeastern markets as well? Sentiment(polarity=0.3181818181818182, subjectivity=0.4772727272727273)
# Kevin Miles - President, Chief Executive Officer & Director
# Yeah. Sentiment(polarity=0.0, subjectivity=0.0)
# We're, again, still very, very excited about Kansas City. Sentiment(polarity=0.48750000000000004, subjectivity=0.9750000000000001)
# It's continued to perform like our model – we expected our model to in a new market. Sentiment(polarity=0.018181818181818174, subjectivity=0.42727272727272725)
# As far as the class of 2013-2014, we really haven't spelled all those out. Sentiment(polarity=0.15000000000000002, subjectivity=0.6)
# We talked about the vintage stores continuing to comp at very nice pace. Sentiment(polarity=0.78, subjectivity=1.0)
# But the 2013-2014 class, although they came out of the ground stronger than our model, you can expect them probably to comp a little bit slightly less, but still comping very well, and at or above our kind of guidance that we've comped and we've spoken of in the past of a comp. Sentiment(polarity=0.03263888888888889, subjectivity=0.3527777777777778)
# Will Slabaugh - Stephens, Inc.
# Got it, got it. Sentiment(polarity=0.0, subjectivity=0.0)
# And then a quick update if you had one on the commodity basket inflation or deflation you might anticipate seeing in the back half. Sentiment(polarity=0.05555555555555555, subjectivity=0.2222222222222222)
# I know you gave the cost of sales guidance for 3Q, but curious if you have any thoughts beyond that into 4Q or what 2016 could potentially look like as you start looking at what you may lock in or may not for next year. Sentiment(polarity=-0.03333333333333333, subjectivity=0.6666666666666666)
# Kevin Miles - President, Chief Executive Officer & Director
# Yeah, so what we're – again we've talked about kind of that slightly below 32% for the full year. Sentiment(polarity=0.2611111111111111, subjectivity=0.5388888888888889)
# We continue to see chicken kind of bounce around a little bit. Sentiment(polarity=-0.0625, subjectivity=0.7833333333333333)
# As we've mentioned to you in the past, it never seems to follow what (25:49) report says it's going to do. Sentiment(polarity=-0.25, subjectivity=0.25)
# But nonetheless, we've seen some decline or even seen some flattening of the tenders to slightly decline, but mostly flat, so still some escalation in the breast market, in the whole chicken market. Sentiment(polarity=-0.14791666666666664, subjectivity=0.41041666666666665)
# What we understand at this point is that will still continue to be at the higher point, but coming down potentially in the back half of the year, with the caveat of reverse migration in Avian flu, any kind of scares that may come from that. Sentiment(polarity=0.08796296296296295, subjectivity=0.4759259259259259)
# Everything else in the basket, though, seems to be relatively stable other than what Jim mentioned on the act of God. Sentiment(polarity=-0.0625, subjectivity=0.1875)
# So we still have some risk there specifically in things like onions and peppers and cucumbers. Sentiment(polarity=0.0, subjectivity=0.0)
# It's pretty significant to our overall produce basket when all three of them are an act of God. Sentiment(polarity=0.20833333333333334, subjectivity=0.625)
# Sort of first year, we've actually seen kind of all three kind of come in and play at the same time. Sentiment(polarity=0.29, subjectivity=0.4716666666666667)
# So, again, I'd point you back, I believe that COGS will come down and be flat to last year and slightly under the 32%, but I think Q3 is still going to be a little high. Sentiment(polarity=-0.05353174603174603, subjectivity=0.241031746031746)
# In Q4 we should start to see some relief. Sentiment(polarity=0.0, subjectivity=0.0)
# Will Slabaugh - Stephens, Inc. Sentiment(polarity=0.0, subjectivity=0.0)
# Thanks. Sentiment(polarity=0.2, subjectivity=0.2)
# That's helpful. Sentiment(polarity=0.0, subjectivity=0.0)
# One quick follow-up if I could on the labor front. Sentiment(polarity=0.3333333333333333, subjectivity=0.5)
# You'd mentioned previously you planned on spending just a little more in some areas on labor, a third GM and some bigger-volume storage potentially. Sentiment(polarity=0.029166666666666674, subjectivity=0.4333333333333333)
# So I'm curious on kind of the updated thoughts there. Sentiment(polarity=0.25, subjectivity=0.95)
# And then separately, you mentioned you didn't expect to take any more price for the year, that maybe more commodity-driven. Sentiment(polarity=0.5, subjectivity=0.5)
# But I'm curious if you would consider maybe into 2016 taking more price if you were to see wage inflation or overall labor cost inflation continue to rise in a more structural basis. Sentiment(polarity=0.225, subjectivity=0.5)
# Kevin Miles - President, Chief Executive Officer & Director
# Yeah, I think it's kind of the way we looked at this year is exactly what you said on the commodity side. Sentiment(polarity=0.425, subjectivity=0.575)
# We've been able to see some significant savings there as we've negotiated our contracts and continue to negotiate. Sentiment(polarity=0.4375, subjectivity=0.75)
# So that's the main reason there. Sentiment(polarity=0.16666666666666666, subjectivity=0.3333333333333333)
# If we were to see whether it be commodity or labor pressures, we would consider taking price. Sentiment(polarity=0.0, subjectivity=0.0)
# I think kind of the way we look at it is we do research every year at the beginning of the year, and we're really four weeks away from taking price at any given point in time. Sentiment(polarity=0.4, subjectivity=0.55)
# So if we needed to do it even in the back half of this year, we could do that. Sentiment(polarity=-0.08333333333333333, subjectivity=0.08333333333333333)
# Our intent is not to do that, though. Sentiment(polarity=0.0, subjectivity=0.0)
# In 2016 again we will reevaluate that. Sentiment(polarity=0.0, subjectivity=0.0)
# We will have some menu introduction in 2016 as well, so some price kind of comes through a new menu innovation. Sentiment(polarity=0.36818181818181817, subjectivity=0.6772727272727272)
# So we would definitely consider price as we do every year. Sentiment(polarity=0.0, subjectivity=0.5)
# James Besch - CFO, Vice President-Accounting & Controller
# And just to add on to your initial question about training stores or three-GM stores, at the end of the second quarter, we had 19 stores that were currently staffed with three GMs. Sentiment(polarity=0.0, subjectivity=0.13333333333333333)
# At that same point in the prior year, we only had 9. Sentiment(polarity=0.0, subjectivity=0.375)
# So I think we continue to anticipate that to be a higher year-over-year cost, and as we continue to add restaurants we'll continue to grow that number. Sentiment(polarity=0.25, subjectivity=0.5)
# Will Slabaugh - Stephens, Inc.
# Great. Sentiment(polarity=0.8, subjectivity=0.75)
# Thanks, guys. Sentiment(polarity=0.2, subjectivity=0.2)
# Kevin Miles - President, Chief Executive Officer & Director
# Thank you. Sentiment(polarity=0.0, subjectivity=0.0)
# Operator
# Thank you. Sentiment(polarity=0.0, subjectivity=0.0)
# Our next question comes from Jason West from Credit Suisse. Sentiment(polarity=0.0, subjectivity=0.0)
# Jason West - Credit Suisse Securities (USA) LLC (Broker)
# Yeah. Sentiment(polarity=0.0, subjectivity=0.0)
# Thanks, guys. Sentiment(polarity=0.2, subjectivity=0.2)
# Can you hear me okay? Sentiment(polarity=0.5, subjectivity=0.5)
# Kevin Miles - President, Chief Executive Officer & Director
# Yes. Sentiment(polarity=0.0, subjectivity=0.0)
# James Besch - CFO, Vice President-Accounting & Controller
# Hey, Jason. Sentiment(polarity=0.0, subjectivity=0.0)
# Jason West - Credit Suisse Securities (USA) LLC (Broker)
# Hi. Sentiment(polarity=0.0, subjectivity=0.0)
# Just couple on G&A. Sentiment(polarity=0.0, subjectivity=0.0)
# The guidance there that went up, does that include the $550,000 item in the quarter? Sentiment(polarity=0.0, subjectivity=0.0)
# And also where were you on stock comp within the G&A now? Sentiment(polarity=0.0, subjectivity=0.0)
# James Besch - CFO, Vice President-Accounting & Controller
# Yeah. Sentiment(polarity=0.0, subjectivity=0.0)
# So the $25.3 million and $25.5 million is excluding the transition costs that occurred in the second quarter. Sentiment(polarity=0.0, subjectivity=0.0)
# And I think previously we had guided stock comp to $1.3 million for the year, and we still feel that's a reasonable estimate. Sentiment(polarity=0.016666666666666677, subjectivity=0.3833333333333333)
# Jason West - Credit Suisse Securities (USA) LLC (Broker)
# Okay. Sentiment(polarity=0.5, subjectivity=0.5)
# And then, on G&A the expenses for the Sarb-Ox compliance, does any of that roll off next year, or is this all sort of run rate expenses that you're going to hold on to going forward? Sentiment(polarity=0.0, subjectivity=0.0)
# James Besch - CFO, Vice President-Accounting & Controller
# Yeah. Sentiment(polarity=0.0, subjectivity=0.0)
# So, the reality the majority of those expenses that we're estimating, a lot of that is going to be recurring costs going forward. Sentiment(polarity=0.0, subjectivity=0.0)
# Kind of the primary pieces of that really are associated with audit requirements, whether external audit or – as well as the fact that we're outsourcing our internal audit function, which is going to take on a even more critical role next year. Sentiment(polarity=0.2125, subjectivity=0.375)
# So we believe the majority of that will carry forward. Sentiment(polarity=0.0, subjectivity=0.0)
# That being said, there is a hope that we'll be able to leverage components of that. Sentiment(polarity=0.5, subjectivity=0.625)
# We hope to gain some additional efficiencies in the audit process. Sentiment(polarity=0.0, subjectivity=0.0)
# And whatever head count we really bring on, we obviously hope to leverage that to help in other areas. Sentiment(polarity=0.025000000000000005, subjectivity=0.35833333333333334)
# Jason West - Credit Suisse Securities (USA) LLC (Broker)
# Okay. Sentiment(polarity=0.5, subjectivity=0.5)
# Got it. Sentiment(polarity=0.0, subjectivity=0.0)
# Helpful. Sentiment(polarity=0.0, subjectivity=0.0)
# And then one other one on the cost in the new stores. Sentiment(polarity=0.005681818181818177, subjectivity=0.4147727272727273)
# Kevin, I believe you said we can expect the 2013 and 2014 stores to comp slightly less. Sentiment(polarity=-0.16666666666666666, subjectivity=0.06666666666666667)
# And I'm not sure if you're saying in terms of them opening at higher volumes so there's just less room to grow into, or are you're saying those stores are comping below the base, if you could kind of clarify what that means? Sentiment(polarity=-0.07333333333333333, subjectivity=0.6711111111111111)
# Kevin Miles - President, Chief Executive Officer & Director
# Yeah, I know. Sentiment(polarity=0.0, subjectivity=0.0)
# I'm sorry about that. Sentiment(polarity=-0.5, subjectivity=1.0)
# No, I mean they've opening up – they opened up at a stronger volume – a stronger opening volume. Sentiment(polarity=0.15625, subjectivity=0.6875)
# So, thus, instead of comping in that first year maybe kind of the 8 to 10 range, they comp in that 6 to 8 range instead, but they're opening up at a much higher volume. Sentiment(polarity=0.3666666666666667, subjectivity=0.5777777777777778)
# Jason West - Credit Suisse Securities (USA) LLC (Broker)
# Okay. Sentiment(polarity=0.5, subjectivity=0.5)
# Got it. Sentiment(polarity=0.0, subjectivity=0.0)
# Thank you. Sentiment(polarity=0.0, subjectivity=0.0)
# Operator
# . Sentiment(polarity=0.0, subjectivity=0.0)
# Our next question comes from Sharon Zackfia from William Blair & Co.
# Sharon M. Zackfia - William Blair & Co. LLC
# Hi. Sentiment(polarity=0.0, subjectivity=0.0)
# Good afternoon. Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# Kevin, can you talk about – I think you were testing some new ovens, what you're seeing with that technology. Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# And then secondarily, any thoughts on small-order delivery? Sentiment(polarity=-0.3, subjectivity=0.3)
# Kevin Miles - President, Chief Executive Officer & Director
# Hey, Sharon. Sentiment(polarity=0.0, subjectivity=0.0)
# Yeah. Sentiment(polarity=0.0, subjectivity=0.0)
# So we still continue to test. Sentiment(polarity=0.0, subjectivity=0.0)
# We've actually expanded that test into, I believe, four more locations, five more locations. Sentiment(polarity=0.3333333333333333, subjectivity=0.3666666666666667)
# ...
# So it's very organic, again pointing back to very little marketing spend driving this. Sentiment(polarity=-0.014583333333333337, subjectivity=0.31666666666666665)
# So it's really that brand awareness and everything that's going. Sentiment(polarity=0.2, subjectivity=0.2)
# So we expect it to remain positive and continue kind of on those same trends throughout the back half of the year and even going into next year. Sentiment(polarity=0.1101010101010101, subjectivity=0.289520202020202)
# I think you could even – hopefully, we'll see some acceleration again as we continue to penetrate and build some of the smaller markets with more locations. Sentiment(polarity=0.25, subjectivity=0.5)
# Dallas is our biggest, and we've seen that now since 2009 continue where traffic and mix continued to grow. Sentiment(polarity=0.0, subjectivity=0.0)
# David E. Tarantino - Robert W. Baird & Co., Inc. (Broker)
# Got it. Sentiment(polarity=0.0, subjectivity=0.0)
# That's helpful. Sentiment(polarity=0.0, subjectivity=0.0)
# And then I guess a follow-up question on SG&A. Sentiment(polarity=0.0, subjectivity=0.0)
# I know that you're still at a very small scale today and there is a lot of investments needed as you scale up the business. Sentiment(polarity=-0.325, subjectivity=0.52)
# But how do you think about that line as you look into maybe next year or the following couple of years, and your ability to leverage that. Sentiment(polarity=0.0, subjectivity=0.05)
# Do you think that the level of investment growth will start to slow and we'll start to see leverage on that or do you it will be more modest leverage as you scale up? Sentiment(polarity=0.09999999999999998, subjectivity=0.6)
# Kevin Miles - President, Chief Executive Officer & Director
# Yeah, I think again it's – we're very excited to be SOX compliant. Sentiment(polarity=0.48750000000000004, subjectivity=0.9750000000000001)
# We're happy that we're in the big league now with the other folks. Sentiment(polarity=0.225, subjectivity=0.4916666666666667)
# It was a little quick, so that acceleration that you're seeing this year obviously will continue on as we go forward. Sentiment(polarity=0.048611111111111105, subjectivity=0.5)
# So there will be a little bit there that was unanticipated. Sentiment(polarity=-0.1875, subjectivity=0.5)
# As soon as it was, we anticipate it to be there but not as soon as we are. Sentiment(polarity=0.0, subjectivity=0.0)
# So with that, we'll continue to invest there. Sentiment(polarity=0.0, subjectivity=0.0)
# So you probably won't see – I think we've always pointed 2015, no acceleration, and maybe slight 2016 is what we said. Sentiment(polarity=-0.16666666666666666, subjectivity=0.16666666666666666)
# I don't know now as we continue to build everything around SOX and our requirements if we will see as much in 2016. Sentiment(polarity=0.2, subjectivity=0.2)
# But I do believe after 2016 – maybe slightly in 2016, you'll start to see that grow through 2017 and out at a nice pace. Sentiment(polarity=0.21666666666666667, subjectivity=0.5833333333333334)
# And kind of the way we originally had modeled it out as is if you kind of take 75% of the revenue growth and model that in, that's kind of how we've looked at the leverage over time. Sentiment(polarity=0.54375, subjectivity=0.8624999999999999)
# But probably seeing that more in 2017. Sentiment(polarity=0.5, subjectivity=0.5)
# David E. Tarantino - Robert W. Baird & Co., Inc. (Broker)
# Great, that's helpful. Sentiment(polarity=0.8, subjectivity=0.75)
# Thank you very much. Sentiment(polarity=0.26, subjectivity=0.26)
# Kevin Miles - President, Chief Executive Officer & Director
# Thank you. Sentiment(polarity=0.0, subjectivity=0.0)
# Operator
# Thank you. Sentiment(polarity=0.0, subjectivity=0.0)
# Our next question comes from Paul Westra from Stifel. Sentiment(polarity=0.0, subjectivity=0.0)
# Paul Westra - Stifel, Nicolaus & Co., Inc.
# Great, thanks. Sentiment(polarity=0.5, subjectivity=0.475)
# Good afternoon. Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# Kevin Miles - President, Chief Executive Officer & Director
# Hey, Paul. Sentiment(polarity=0.0, subjectivity=0.0)
# Paul Westra - Stifel, Nicolaus & Co., Inc.
# My first question is on a little bit more color on the operating expense line. Sentiment(polarity=0.1875, subjectivity=0.4444444444444444)
# I know you mentioned it was up 140 basis points year-over-year if you exclude the impact of the manager meeting. Sentiment(polarity=0.0, subjectivity=0.0)
# It still seems – a little more color other than higher occupancy expense could maybe help out. Sentiment(polarity=0.109375, subjectivity=0.46875)
# And the 2Q number, even adjusted, was higher than the 1Q number, which hasn't been the case in the past. Sentiment(polarity=0.0, subjectivity=0.375)
# So just trying to get a feel where that number is heading and maybe some commentary on the second half whether you expect that line to be levered or maybe see some deleverage? Sentiment(polarity=-0.08333333333333333, subjectivity=0.08333333333333333)
# James Besch - CFO, Vice President-Accounting & Controller
# Yeah, thanks, Paul, this is Jim. Sentiment(polarity=0.2, subjectivity=0.2)
# A lot of the store operating expense line comes down to really the comparison year-over-year. Sentiment(polarity=0.022222222222222213, subjectivity=0.24444444444444446)
# Last year, we had bit more volatility as we mentioned due to issues with our maintenance provider. Sentiment(polarity=0.125, subjectivity=0.3138888888888889)
# What that resulted in was some inconsistencies from quarter-to-quarter primarily in the repair and maintenance line. Sentiment(polarity=0.15000000000000002, subjectivity=0.25)
# In the current year, with service channel in place, it's giving us much more insight into our expense, helping us really monitor the expense. Sentiment(polarity=0.2333333333333333, subjectivity=0.3666666666666667)
# But what we're seeing this year is a very normalized flattened-out expense as opposed to some of the up-and-down spikes that we saw in the previous years. Sentiment(polarity=0.016666666666666677, subjectivity=0.23333333333333334)
# So I think what you'll see for the remainder of this year is a much more normalized line on that operating expense, especially R&M, and it's going to lead to much more, much better comp for next year. Sentiment(polarity=0.3, subjectivity=0.5)
# Paul Westra - Stifel, Nicolaus & Co., Inc. Sentiment(polarity=0.0, subjectivity=0.0)
# Thanks. Sentiment(polarity=0.2, subjectivity=0.2)
# I recall last year – this was in the third quarter – had some actual – some spiking higher expenses in that line. Sentiment(polarity=0.0625, subjectivity=0.16666666666666669)
# Was that...
# James Besch - CFO, Vice President-Accounting & Controller
# That's exactly right. Sentiment(polarity=0.2857142857142857, subjectivity=0.5357142857142857)
# In the third quarter we did see some of the uptick back up in the R&M. Sentiment(polarity=0.0, subjectivity=0.0)
# So, obviously, there's a hope that we'll be much a closer percentage next year. Sentiment(polarity=0.06666666666666667, subjectivity=0.2333333333333333)
# But on that same token, in the fourth quarter of last year, we saw the R&M tick back down. Sentiment(polarity=-0.031111111111111117, subjectivity=0.09611111111111112)
# So like I said, there was just a lot of inconsistencies in the prior-year number, and I think what we'll see is a nice flatter line this year and going forward. Sentiment(polarity=0.25, subjectivity=0.5)
# Paul Westra - Stifel, Nicolaus & Co., Inc.
# Great. Sentiment(polarity=0.8, subjectivity=0.75)
# A question on development. Sentiment(polarity=0.0, subjectivity=0.0)
# You have seven already opened this – so far in the quarter. Sentiment(polarity=0.1, subjectivity=1.0)
# Should we expect any more for the third quarter, new units as far as modeling? Sentiment(polarity=0.18409090909090908, subjectivity=0.48863636363636365)
# Kevin Miles - President, Chief Executive Officer & Director
# Yes, we have a couple of more coming into – roughly three to four coming into Q3 that we'll finish up, and then we'll finish the rest in Q4. Sentiment(polarity=0.2, subjectivity=0.45)
# Paul Westra - Stifel, Nicolaus & Co., Inc.
# Great. Sentiment(polarity=0.8, subjectivity=0.75)
# And then looking out to next year's development, still looking for maybe 25% of total development being in new markets. Sentiment(polarity=0.04545454545454545, subjectivity=0.40151515151515155)
# And would you qualify just Denver and KC to make up those roughly eight stores in new market that was (39:17). Sentiment(polarity=0.018181818181818174, subjectivity=0.42727272727272725)
# Kevin Miles - President, Chief Executive Officer & Director
# That's correct. Sentiment(polarity=0.0, subjectivity=0.0)
# I think those would be the two markets that you'll see that new development. Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# And as we talked, it was up to 25%. Sentiment(polarity=0.0, subjectivity=0.0)
# In 2015, the only new store that will be opened in the new market is the Kansas City store, so you can assume that the rest of the stores were all in existing markets. Sentiment(polarity=0.0909090909090909, subjectivity=0.6363636363636364)
# But in 2016, you will definite see that 25% number going out because of the sites that we already have signed in both Kansas City and in Denver alike. Sentiment(polarity=0.0, subjectivity=0.5)
# Paul Westra - Stifel, Nicolaus & Co., Inc.
# Great. Sentiment(polarity=0.8, subjectivity=0.75)
# And then maybe lastly just on your comp guidance for the year, you've obviously raised it on a full-year basis. Sentiment(polarity=0.0, subjectivity=0.2833333333333333)
# It kind of implies a range maybe somewhere in the neighborhood of 3.5% to 5.5% for the rest of the year. Sentiment(polarity=0.6, subjectivity=0.9)
# And maybe just talk about what might have occurred to put you in the low end or high end, and maybe how we should think about it. Sentiment(polarity=0.08, subjectivity=0.41999999999999993)
# Obviously, your 2Q comp is slightly above that range now. Sentiment(polarity=0.0, subjectivity=0.3)
# And I know some price is falling off, but should we look at it on a two-year basis or if things are good, we'll land here, or roughly, something like – yeah? Sentiment(polarity=0.3, subjectivity=0.5)
# Kevin Miles - President, Chief Executive Officer & Director
# Yeah. Sentiment(polarity=0.0, subjectivity=0.0)
# I think, Paul – I mean, I think, barring any kind of macroeconomic things, I think you're going to see us continue the trends we have. Sentiment(polarity=0.14375, subjectivity=0.79375)
# We feel very confident in that 5% to 6% range. Sentiment(polarity=0.65, subjectivity=1.0)
# Kind of back to the two-year stats we've kind of really been in that 13%-ish kind of range for a while, kind of low double-digit two year stat. Sentiment(polarity=0.37142857142857144, subjectivity=0.5857142857142856)
# So we feel very confident that moving through Q3-Q4 we're going to remain in that same range. Sentiment(polarity=0.325, subjectivity=0.5625)
# James Besch - CFO, Vice President-Accounting & Controller
# Yeah. Sentiment(polarity=0.0, subjectivity=0.0)
# And just to add to that keeping in mind, we won't have price in the second half of the year. Sentiment(polarity=-0.08333333333333333, subjectivity=0.08333333333333333)
# So if you were really looking at – within that implied rate, it definitely does imply kind of a 3.7% to 5.7% type of range. Sentiment(polarity=0.26666666666666666, subjectivity=0.5333333333333333)
# Kevin Miles - President, Chief Executive Officer & Director
# Yeah just a point – one other point, I think, it's roughly – in Q3-Q4, it's roughly 70 basis points of price that's rolled off, if you kind of adjust for the back half of the year of the 1.3% price overall. Sentiment(polarity=0.015476190476190473, subjectivity=0.32023809523809527)
# Paul Westra - Stifel, Nicolaus & Co., Inc.
# All right. Sentiment(polarity=0.2857142857142857, subjectivity=0.5357142857142857)
# Good stuff. Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# Right. Sentiment(polarity=0.2857142857142857, subjectivity=0.5357142857142857)
# Congrats on a good quarter. Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# Thanks. Sentiment(polarity=0.2, subjectivity=0.2)
# James Besch - CFO, Vice President-Accounting & Controller
# Thank you. Sentiment(polarity=0.0, subjectivity=0.0)
# Kevin Miles - President, Chief Executive Officer & Director
# Thanks. Sentiment(polarity=0.2, subjectivity=0.2)
# Operator
# Thank you. Sentiment(polarity=0.0, subjectivity=0.0)
# Our last question comes from Stephen Anderson from Maxim Group. Sentiment(polarity=0.0, subjectivity=0.06666666666666667)
# Stephen Anderson - Maxim Group
# Yes. Sentiment(polarity=0.0, subjectivity=0.0)
# Hello. Sentiment(polarity=0.0, subjectivity=0.0)
# Good afternoon. Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# Just I thought I wanted to call and ask about, I know some of the other dayparts have been mentioned, but I wanted to avail a little more color on dinner. Sentiment(polarity=0.0625, subjectivity=0.4583333333333333)
# I know it's been something that you've been trying to grow for the last couple of quarters, and so I just wanted to and I just want to see if there's anything that we should know about in terms of any other entrées that may carry a higher average ticket that you might see having an impact. Sentiment(polarity=-0.006249999999999999, subjectivity=0.33541666666666664)
# Kevin Miles - President, Chief Executive Officer & Director
# Nothing this year. Sentiment(polarity=0.0, subjectivity=0.0)
# We continued to grow. Sentiment(polarity=0.0, subjectivity=0.0)
# It's still tracking kind of exclusive of catering around the 40% of overall sales. Sentiment(polarity=0.3, subjectivity=0.45)
# Again, we're doing cuttings and tastings now for what we will roll out in 2016. Sentiment(polarity=0.0, subjectivity=0.0)
# And so, again, our focus around menu items will still be around attachment and still be around mostly dinner and catering opportunities, not as much around the lunch daypart. Sentiment(polarity=0.35, subjectivity=0.35)
# We feel very strongly of where we are at lunch. Sentiment(polarity=0.5633333333333334, subjectivity=0.9533333333333333)
# That said, you may see us over time do some more enhancements in our lunch menu, but – and our lunch offering. Sentiment(polarity=0.5, subjectivity=0.5)
# That said, I think some of the items we have, we have some pricing ability specifically around dinner, so we'll continue to look and focus on that as we drive this dinner daypart. Sentiment(polarity=0.0, subjectivity=0.0)
# Stephen Anderson - Maxim Group
# All right. Sentiment(polarity=0.2857142857142857, subjectivity=0.5357142857142857)
# Thank you. Sentiment(polarity=0.0, subjectivity=0.0)
# Kevin Miles - President, Chief Executive Officer & Director
# Thanks. Sentiment(polarity=0.2, subjectivity=0.2)
# Operator
# Thank you. Sentiment(polarity=0.0, subjectivity=0.0)
# I'll now turn the call back over to Kevin Miles for closing comments. Sentiment(polarity=0.0, subjectivity=0.0)
# Kevin Miles - President, Chief Executive Officer & Director
# Thank you. Sentiment(polarity=0.0, subjectivity=0.0)
# Again, thanks everyone for joining our call and your interest in our company. Sentiment(polarity=0.2, subjectivity=0.2)
# We'd love to have you live Zoe's and join us at one of our locations across the country. Sentiment(polarity=0.3181818181818182, subjectivity=0.55)
# And if we're not in your area now, we look forward to bringing a Zoe's to a community near you soon. Sentiment(polarity=0.1, subjectivity=0.4)
# Thank you again. Sentiment(polarity=0.0, subjectivity=0.0)
# Operator
# Thank you. Sentiment(polarity=0.0, subjectivity=0.0)
# This does conclude today's teleconference. Sentiment(polarity=0.0, subjectivity=0.0)
# You may disconnect your lines at this time. Sentiment(polarity=0.0, subjectivity=0.0)
# Thank you for your participation. Sentiment(polarity=0.0, subjectivity=0.0)
