# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('gapminder_with_missing.tsv', sep='\t')

# %%
data=data.drop('Unnamed: 0', axis='columns')

# %%
data.head()
# Out:
#    Unnamed: 0      country continent  year  lifeExp       pop   gdpPercap
# 0           0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1           1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2           2  Afghanistan      Asia  1962   31.997  10267083   -1.000000
# 3           3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4           4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
data.gdpPercap.mean()
# Out:
# 6833.852739445185

# %%
data=data.replace(-1, np.nan)

# %%
data.head()
# Out:
#    Unnamed: 0      country continent  year  lifeExp         pop   gdpPercap
# 0           0  Afghanistan      Asia  1952   28.801   8425333.0  779.445314
# 1           1  Afghanistan      Asia  1957   30.332   9240934.0  820.853030
# 2           2  Afghanistan      Asia  1962   31.997  10267083.0         NaN
# 3           3  Afghanistan      Asia  1967   34.020  11537966.0  836.197138
# 4           4  Afghanistan      Asia  1972   36.088  13079460.0  739.981106

# %%
data.gdpPercap.mean()
# Out:
# 7201.590641938526

# %%
data['gdpPercap'].isnull()
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 1674    False
# 1675    False
# 1676    False
# 1677    False
# 1678    False
# 1679    False
# 1680    False
# 1681    False
# 1682    False
# 1683    False
# 1684    False
# 1685    False
# 1686    False
# 1687    False
# 1688    False
# 1689     True
# 1690    False
# 1691    False
# 1692    False
# 1693    False
# 1694    False
# 1695    False
# 1696    False
# 1697    False
# 1698    False
# 1699    False
# 1700    False
# 1701    False
# 1702    False
# 1703    False
# ...

# %%
data[ data['gdpPercap'].isnull()]
# Out:
#       Unnamed: 0                   country continent  year  lifeExp  \
# 2              2               Afghanistan      Asia  1962   31.997
# 42            42                    Angola    Africa  1982   39.942
# 73            73                   Austria    Europe  1957   67.480
# 102          102                Bangladesh      Asia  1982   50.009
# 178          178                    Brazil  Americas  2002   71.006
# 179          179                    Brazil  Americas  2007   72.390
# 185          185                  Bulgaria    Europe  1977   70.810
# 200          200              Burkina Faso    Africa  1992   50.260
# 240          240                    Canada  Americas  1952   68.750
# 259          259  Central African Republic    Africa  1987   50.485
# 268          268                      Chad    Africa  1972   45.569
# 297          297                     China      Asia  1997   70.426
# 321          321                   Comoros    Africa  1997   60.660
# ...

# %%
data2=data.dropna()

# %%
data.head()
# Out:
#    Unnamed: 0      country continent  year  lifeExp         pop   gdpPercap
# 0           0  Afghanistan      Asia  1952   28.801   8425333.0  779.445314
# 1           1  Afghanistan      Asia  1957   30.332   9240934.0  820.853030
# 2           2  Afghanistan      Asia  1962   31.997  10267083.0         NaN
# 3           3  Afghanistan      Asia  1967   34.020  11537966.0  836.197138
# 4           4  Afghanistan      Asia  1972   36.088  13079460.0  739.981106

# %%
data.fillna(0.0);

# %%
data.fillna(method='ffill');

# %%
avg_gdp=data.gdpPercap.mean()

# %%
data['imputed_gdpPercap']= data.gdpPercap.fillna(avg_gdp)

# %%
????

# %%
data.fillna?

# %%
data2 = pd.read_csv('gapminder_with_corrupt.tsv', sep='\t')

# %%
data2.dtypes
# Out:
# Unnamed: 0     int64
# country       object
# continent     object
# year           int64
# lifeExp       object
# pop           object
# gdpPercap     object
# dtype: object

# %%
data2.head()
# Out:
#    Unnamed: 0      country continent  year             lifeExp       pop  \
# 0           0  Afghanistan      Asia  1952              28.801   8425333
# 1           1  Afghanistan      Asia  1957  30.331999999999997   9240934
# 2           2  Afghanistan      Asia  1962              31.997  10267083
# 3           3  Afghanistan      Asia  1967               34.02  11537966
# 4           4  Afghanistan      Asia  1972              36.088  13079460
#
#            gdpPercap
# 0        779.4453145
# 1      820.8530296nn
# 2  853.1007099999999
# 3        836.1971382
# 4  739.9811057999999

# %%
data2['gdpPercap2']=pd.to_numeric(data2.gdpPercap, errors='coerce')

# %%
data2.head()
# Out:
#    Unnamed: 0      country continent  year             lifeExp       pop  \
# 0           0  Afghanistan      Asia  1952              28.801   8425333
# 1           1  Afghanistan      Asia  1957  30.331999999999997   9240934
# 2           2  Afghanistan      Asia  1962              31.997  10267083
# 3           3  Afghanistan      Asia  1967               34.02  11537966
# 4           4  Afghanistan      Asia  1972              36.088  13079460
#
#            gdpPercap  gdpPercap2
# 0        779.4453145  779.445314
# 1      820.8530296nn         NaN
# 2  853.1007099999999  853.100710
# 3        836.1971382  836.197138
# 4  739.9811057999999  739.981106

# %%
data2.dtypes
# Out:
# Unnamed: 0      int64
# country        object
# continent      object
# year            int64
# lifeExp        object
# pop            object
# gdpPercap      object
# gdpPercap2    float64
# dtype: object

# %%
data2.gdpPercap2.mean()
# Out:
# 7186.243429043534

# %%
data2.gdpPercap2.fillna(method='ffill')
# Out:
# 0        779.445314
# 1        779.445314
# 2        853.100710
# 3        836.197138
# 4        739.981106
# 5        786.113360
# 6        978.011439
# 7        852.395945
# 8        649.341395
# 9        635.341351
# 10       726.734055
# 11       974.580338
# 12      1601.056136
# 13      1942.284244
# 14      2312.888958
# 15      2760.196931
# 16      3313.422188
# 17      3533.003910
# 18      3630.880722
# 19      3738.932735
# 20      2497.437901
# 21      3193.054604
# 22      4604.211737
# 23      5937.029526
# 24      2449.008185
# 25      3013.976023
# 26      2550.816880
# 27      3246.991771
# 28      4182.663766
# 29      4182.663766
#            ...
# 1674    1977.557010
# 1675    1971.741538
# 1676    1879.496673
# 1677    2117.484526
# 1678    2234.820827
# 1679    2280.769906
# 1680    1147.388831
# 1681    1311.956766
# 1682    1452.725766
# 1683    1777.077318
# 1684    1773.498265
# 1685    1588.688299
# 1686    1408.678565
# 1687    1213.315116
# ...
