# %%
import pandas as pd

# %%
import seaborn as sns

# %%
# print graphs in the document
# %matplotlib inline

# %% [markdown]
# 1- Load the Gapminder dataset

# %%
data = pd.read_csv('../data/gapminder.tsv', sep='\t')

# %%
data.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %% [markdown]
# 2- Relate per capita GDP to life expectancy using a scatter plot

# %%
data.corr()
# Out:
#                year   lifeExp       pop  gdpPercap
# year       1.000000  0.435611  0.082308   0.227318
# lifeExp    0.435611  1.000000  0.064955   0.583706
# pop        0.082308  0.064955  1.000000  -0.025600
# gdpPercap  0.227318  0.583706 -0.025600   1.000000

# %%
sns.relplot(x='lifeExp', y='gdpPercap', data=data)

# %% [markdown]
# 2- Use color to differentiate between the different years

# %%
sns.relplot(x='lifeExp', y='gdpPercap', hue='continent', data=data)

# %% [markdown]
# 4- Can you account for population size? Try changing the size of the dots

# %%
sns.relplot(x='lifeExp', y='gdpPercap', size='pop', hue='continent', sizes=(5,200), data=data)

# %%
slice=data[data.year==1952]
sns.relplot(x='lifeExp', y='gdpPercap', size='pop', hue='continent', sizes=(5,200), data=slice)

# %%
max(data.year)
# Out:
# 2007

# %%
slice=data[data.year==2007]
sns.relplot(x='lifeExp', y='gdpPercap', size='pop', hue='continent', sizes=(5,200), data=slice)

# %% [markdown]
# 5- Use facets to break this plot into one plot per year

# %%
data['decade']=pd.cut(data.year, [1950, 1960, 1970, 1980, 1990, 2000, 2010])

# %%
sns.relplot(x='lifeExp', y='gdpPercap', size='pop', hue='continent', col='decade', sizes=(5,200), data=data)

# %% [markdown]
# 6- how does life expectancy vary per continent?

# %%
sns.catplot(y='continent', x='lifeExp', kind='boxen', col='year', data=data)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ...

# %%
sns.relplot(x='continent', y='lifeExp', kind='scatter',  data=data)

# %% [markdown]
# 7- how did life expectancy change over time?

# %%
sns.relplot(x='year', y='lifeExp', kind='line', hue='continent', data=data)
