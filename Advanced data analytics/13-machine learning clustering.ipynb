# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()  # for plot styling
import numpy as np
from sklearn.cluster import KMeans
import pandas as pd

# %%
data=pd.read_json('../data/cars.json')

# %%
data.head()
# Out:
#    Acceleration  Cylinders  Displacement  Horsepower  Miles_per_Gallon  \
# 0          12.0          8         307.0       130.0              18.0
# 1          11.5          8         350.0       165.0              15.0
# 2          11.0          8         318.0       150.0              18.0
# 3          12.0          8         304.0       150.0              16.0
# 4          10.5          8         302.0       140.0              17.0
#
#                         Name Origin  Weight_in_lbs        Year
# 0  chevrolet chevelle malibu    USA           3504  1970-01-01
# 1          buick skylark 320    USA           3693  1970-01-01
# 2         plymouth satellite    USA           3436  1970-01-01
# 3              amc rebel sst    USA           3433  1970-01-01
# 4                ford torino    USA           3449  1970-01-01

# %%
data['year']=pd.to_datetime(data.Year).dt.year
data=data.dropna()

# %%
data.dtypes
# Out:
# Acceleration        float64
# Cylinders             int64
# Displacement        float64
# Horsepower          float64
# Miles_per_Gallon    float64
# Name                 object
# Origin               object
# Weight_in_lbs         int64
# Year                 object
# year                  int64
# dtype: object

# %%
X=data.select_dtypes(exclude=['object'])#.drop(['Cylinders', 'Horsepower'], axis=1)

# %%
X.head()
# Out:
#    Acceleration  Cylinders  Displacement  Horsepower  Miles_per_Gallon  \
# 0          12.0          8         307.0       130.0              18.0
# 1          11.5          8         350.0       165.0              15.0
# 2          11.0          8         318.0       150.0              18.0
# 3          12.0          8         304.0       150.0              16.0
# 4          10.5          8         302.0       140.0              17.0
#
#    Weight_in_lbs  year  cluster
# 0           3504  1970        2
# 1           3693  1970        1
# 2           3436  1970        2
# 3           3433  1970        2
# 4           3449  1970        2

# %%
X.describe()
# Out:
#        Acceleration   Cylinders  Displacement  Horsepower  Miles_per_Gallon  \
# count    392.000000  392.000000    392.000000  392.000000        392.000000
# mean      15.541327    5.471939    194.411990  104.469388         23.445918
# std        2.758864    1.705783    104.644004   38.491160          7.805007
# min        8.000000    3.000000     68.000000   46.000000          9.000000
# 25%       13.775000    4.000000    105.000000   75.000000         17.000000
# 50%       15.500000    4.000000    151.000000   93.500000         22.750000
# 75%       17.025000    8.000000    275.750000  126.000000         29.000000
# max       24.800000    8.000000    455.000000  230.000000         46.600000
#
#        Weight_in_lbs         year     cluster
# count     392.000000   392.000000  392.000000
# mean     2977.584184  1976.051020    0.852041
# std       849.402560     3.788858    0.866274
# min      1613.000000  1970.000000    0.000000
# 25%      2225.250000  1973.000000    0.000000
# 50%      2803.500000  1976.000000    1.000000
# 75%      3614.750000  1979.000000    2.000000
# max      5140.000000  1982.000000    2.000000

# %% [markdown]
# # Estimate clusters

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(X)
y_kmeans = kmeans.predict(X)

# %%
data['cluster']=y_kmeans

# %%
data.groupby('cluster').mean()
# Out:
#          Acceleration  Cylinders  Displacement  Horsepower  Miles_per_Gallon  \
# cluster
# 0           13.463333   7.866667    344.144444  157.811111         14.635556
# 1           16.334444   4.038889    107.208333   77.166667         29.651667
# 2           15.904098   5.819672    212.614754  105.401639         20.789344
#
#          Weight_in_lbs         year
# cluster
# 0          4236.322222  1974.022222
# 1          2222.827778  1976.816667
# 2          3162.581967  1976.418033

# %%
sns.relplot(y='Acceleration', x='Displacement', hue='cluster', data=data)

# %%
sns.catplot(y='Miles_per_Gallon', x='cluster', data=data)

# %%
sns.catplot(y='Acceleration', x='Cylinders', hue='cluster', data=data)

# %%
sns.relplot(y='Acceleration', x='Horsepower', hue='cluster', data=data)
